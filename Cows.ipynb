# %%
import pandas as pd

# %%
paths = {
    'win10': '',
    'win11': r'C:\Users\Administrator\Downloads\Emissions_Totals_E_All_Data',
}

# %%
import platform

windows_version = platform.release()

if windows_version.startswith("10"):
    path = paths['win10']
elif windows_version.startswith("11"):
    path = paths['win11']

# %%
emissions_total     = 'Emissions_Totals_E_All_Data.csv'
emissions_noflag    = 'Emissions_Totals_E_All_Data_NOFLAG.csv'
flags               = 'Emissions_Totals_E_Flags.csv'
area_codes          = 'Emissions_Totals_E_AreaCodes.csv'

# %%
df_emissions_total = pd.read_csv(f'{path}\\{emissions_total}', encoding='latin-1')

# %%
df_emissions_total
# Out:
#        Area Code Area Code (M49)         Area  Item Code  \
# 0              2            '004  Afghanistan       5064
# 1              2            '004  Afghanistan       5064
# 2              2            '004  Afghanistan       5064
# 3              2            '004  Afghanistan       5064
# 4              2            '004  Afghanistan       5064
# ...          ...             ...          ...        ...
# 66503       5873            '198         OECD       6829
# 66504       5873            '198         OECD       6829
# 66505       5873            '198         OECD       6829
# 66506       5873            '198         OECD       6829
# 66507       5873            '198         OECD       6829
#
#                              Item  Element Code  \
# 0                   Crop Residues          7234
# 1                   Crop Residues          7236
# 2                   Crop Residues          7230
# 3                   Crop Residues        724313
# ...

# %%
df_emissions_total_ch4 = df_emissions_total[df_emissions_total['Element'].str.contains('CH4')]
# df_emissions_total_ch4['Item'].unique()

# %%
df_emissions_total_ch4[df_emissions_total_ch4['Item'] == 'Manure Management']
# Out:
#        Area Code Area Code (M49)                   Area  Item Code  \
# 24             2            '004            Afghanistan       5059
# 25             2            '004            Afghanistan       5059
# 29             2            '004            Afghanistan       5059
# 30             2            '004            Afghanistan       5059
# 269            3            '008                Albania       5059
# ...          ...             ...                    ...        ...
# 65990       5849            '908  Non-Annex I countries       5059
# 65995       5849            '908  Non-Annex I countries       5059
# 65996       5849            '908  Non-Annex I countries       5059
# 66282       5873            '198                   OECD       5059
# 66286       5873            '198                   OECD       5059
#
#                     Item  Element Code                           Element  \
# 24     Manure Management          7225                   Emissions (CH4)
# ...

# %%
df_emmissions_noflag = pd.read_csv(f'{path}\\{emissions_noflag}', encoding='latin-1')
df_emmissions_noflag
# Out:
#        Area Code Area Code (M49)         Area  Item Code  \
# 0              2            '004  Afghanistan       5064
# 1              2            '004  Afghanistan       5064
# 2              2            '004  Afghanistan       5064
# 3              2            '004  Afghanistan       5064
# 4              2            '004  Afghanistan       5064
# ...          ...             ...          ...        ...
# 66503       5873            '198         OECD       6829
# 66504       5873            '198         OECD       6829
# 66505       5873            '198         OECD       6829
# 66506       5873            '198         OECD       6829
# 66507       5873            '198         OECD       6829
#
#                              Item  Element Code  \
# 0                   Crop Residues          7234
# 1                   Crop Residues          7236
# 2                   Crop Residues          7230
# 3                   Crop Residues        724313
# ...
